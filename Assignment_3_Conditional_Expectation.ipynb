# %% [markdown]
# <a href="https://colab.research.google.com/github/GR0409/Statistical-Learning-e21091/blob/main/Assignment_3_Conditional_Expectation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Q1) Prediction of fraudulent transactions

# %% [markdown]
# A bank monitors credit-card transactions for possible fraud.
#
# For each transaction, let the sample space be
#
# $$
# \Omega=\{\omega_1,\omega_2,\omega_3,\omega_4\},
# $$
#
# where:
#
# * $\omega_1$: low-risk customer, legitimate transaction,
# * $\omega_2$: low-risk customer, fraudulent transaction,
# * $\omega_3$: high-risk customer, legitimate transaction,
# * $\omega_4$: high-risk customer, fraudulent transaction.
#
# Assume the probabilities are
#
# $$
# P(\{\omega_1\})=0.50,\qquad
# P(\{\omega_2\})=0.10,\qquad
# P(\{\omega_3\})=0.20,\qquad
# P(\{\omega_4\})=0.20.
# $$
#
# Let $X:\Omega\to\mathbb R$ denote the fraud indicator:
#
# $$
# X(\omega_1)=0,\qquad
# X(\omega_2)=1,\qquad
# X(\omega_3)=0,\qquad
# X(\omega_4)=1.
# $$
#
# Thus $X=1$ means the transaction is fraudulent, and $X=0$ means it is legitimate.
#
# Now suppose the bank does not observe the full outcome $\omega$, but only the customer's risk class. Define $Y:\Omega\to\mathbb R$ by
#
# $$
# Y(\omega_1)=0,\qquad
# Y(\omega_2)=0,\qquad
# Y(\omega_3)=1,\qquad
# Y(\omega_4)=1.
# $$
#
# Thus:
#
# * $Y=0$ means “low-risk customer,”
# * $Y=1$ means “high-risk customer.”
#
# Answer the following.

# %% [markdown]
# 1. Write down the probability space $(\Omega,\mathfrak F,P)$, where $\mathfrak F=\mathfrak P(\Omega)$.
#
# $$\Omega = \{\omega_1, \omega_2, \omega_3, \omega_4\}$$
#
# $$\mathfrak{F} = \{\emptyset, \{\omega_1\}, \{\omega_2\}, \{\omega_3\}, \{\omega_4\}, \{\omega_1, \omega_2\}, \dots, \Omega\}$$
#
# $$A \in \mathfrak{F}$ as $P(A) = \sum_{\omega \in A} P(\{\omega\})$$
#
# $$P(\{\omega_1\}) = 0.50, \quad P(\{\omega_2\}) = 0.10, \quad P(\{\omega_3\}) = 0.20, \quad P(\{\omega_4\}) = 0.20$$
#
# <br>
#
# 2. Compute the $\sigma$-algebra generated by $Y$, namely $\sigma(Y)$.
#
# $Y=0$ for the set $\{\omega_1, \omega_2\}$
#
# $Y=1$ for the set $\{\omega_3, \omega_4\}$
#
# $\sigma(Y) = \{\emptyset, \{\omega_1, \omega_2\}, \{\omega_3, \omega_4\}, \Omega\}$
#
# <br>
#
# 3. Explain why $E[X\mid Y]$ must be $\sigma(Y)$-measurable, and therefore must be constant on the sets $\{ \omega_1,\omega_2\}$ and $\{\omega_3,\omega_4\}$.
#
# By definition, $E[X \mid Y]$ must be $\sigma(Y)$-measurable, meaning it must be constant on the fundamental sets (atoms) of $\sigma(Y)$. Since the atoms of $\sigma(Y)$ are exactly $\{\omega_1, \omega_2\}$ and $\{\omega_3, \omega_4\}$, $E[X \mid Y]$ must take one constant value on the first set and another on the second.
#
# <br>
#
# 4. Compute $E[X\mid Y]$ explicitly and show that
#
# $$
# E[X\mid Y]= \frac{1}{6} \mathbb{1}_{\{Y=0\}} + \frac{1}{2} \mathbb{1}_{\{Y=1\}}
# $$
#
# For $Y=0$ (Set $\{\omega_1, \omega_2\}$) - $$E[X \mid Y=0] = \frac{X(\omega_1)P(\{\omega_1\}) + X(\omega_2)P(\{\omega_2\})}{P(\{\omega_1, \omega_2\})}$$
#
# $$E[X \mid Y=0] = \frac{0(0.50) + 1(0.10)}{0.50 + 0.10} = \frac{0.10}{0.60} = \frac{1}{6}$$
#
# For $Y=1$ (Set $\{\omega_3, \omega_4\}$) - $$E[X \mid Y=1] = \frac{X(\omega_3)P(\{\omega_3\}) + X(\omega_4)P(\{\omega_4\})}{P(\{\omega_3, \omega_4\})}$$
#
# $$E[X \mid Y=1] = \frac{0(0.20) + 1(0.20)}{0.20 + 0.20} = \frac{0.20}{0.40} = \frac{1}{2}$$
#
# $$E[X \mid Y] = \frac{1}{6} 1_{\{Y=0\}} + \frac{1}{2} 1_{\{Y=1\}}$$
#
# <br>
#
# 5. Verify the defining property of conditional expectation by checking that for every set $A\in\sigma(Y)$,
#
# $$
# \int_A E[X\mid Y]\,dP=\int_A X\,dP.
# $$
#
# $A = \{\omega_1, \omega_2\}$ -
#
# $$\int_A X dP = X(\omega_1)P(\{\omega_1\}) + X(\omega_2)P(\{\omega_2\}) = 0(0.50) + 1(0.10) = 0.10$$
#
# $$\int_A E[X \mid Y] dP = E[X \mid Y=0] \cdot P(A) = \frac{1}{6}(0.60) = 0.10$$
#
# $A = \{\omega_3, \omega_4\}$ -
#
# $$\int_A X dP = X(\omega_3)P(\{\omega_3\}) + X(\omega_4)P(\{\omega_4\}) = 0(0.20) + 1(0.20) = 0.20$$
#
# $$\int_A E[X \mid Y] dP = E[X \mid Y=1] \cdot P(A) = \frac{1}{2}(0.40) = 0.20$$
#
# $A = \Omega$,
#
# $$\int_\Omega X dP = 0.10 + 0.20 = 0.30$$$$\int_\Omega E[X \mid Y] dP = 0.10 + 0.20 = 0.30$$
#
# <br>
#
# 6. Find the Conditional PMF $p_{X|Y}(x \mid y)$.
#
# $p_{X|Y}(x \mid y) = \frac{P(X=x, Y=y)}{P(Y=y)}$
#
# $y=0$,
#
# $$p_{X|Y}(0 \mid 0) = \frac{0.50}{0.60} = \frac{5}{6}$$$$p_{X|Y}(1 \mid 0) = \frac{0.10}{0.60} = \frac{1}{6}$$
#
# $y=1$,
#
# $$p_{X|Y}(0 \mid 1) = \frac{0.20}{0.40} = \frac{1}{2}$$$$p_{X|Y}(1 \mid 1) = \frac{0.20}{0.40} = \frac{1}{2}$$
#
# <br>
#
# 7. Verify the identity:
# $$\mathbb{E}[X\mid Y=y] = \sum_{x \in \{0,1\}} x \cdot p_{X|Y}(x \mid y)$$
#
# $y=0$,
#
# $$\text{LHS} = \mathbb{E}[X \mid Y=0] = \frac{1}{6}$$
#
# $$\text{RHS} = 0 \cdot p_{X|Y}(0 \mid 0) + 1 \cdot p_{X|Y}(1 \mid 0) = 0\left(\frac{5}{6}\right) + 1\left(\frac{1}{6}\right) = \frac{1}{6}$$
#
# $y=1$,
#
# $$\text{LHS} = \mathbb{E}[X \mid Y=1] = \frac{1}{2}$$
#
# $$\text{RHS} = 0 \cdot p_{X|Y}(0 \mid 1) + 1 \cdot p_{X|Y}(1 \mid 1) = 0\left(\frac{1}{2}\right) + 1\left(\frac{1}{2}\right) = \frac{1}{2}$$
#
# <br>
#
# 8. Calculate the **Mean Square Error (MSE)**
#
# $$\text{MSE} = \sum_{i=1}^4 (X(\omega_i) - \mathbb{E}[X \mid Y](\omega_i))^2 P(\{\omega_i\})$$
#
# $$\text{MSE} = \left(0 - \frac{1}{6}\right)^2(0.50) + \left(1 - \frac{1}{6}\right)^2(0.10) + \left(0 - \frac{1}{2}\right)^2(0.20) + \left(1 - \frac{1}{2}\right)^2(0.20)$$
#
# $$\text{MSE} = \left(\frac{1}{36}\right)\left(\frac{1}{2}\right) + \left(\frac{25}{36}\right)\left(\frac{1}{10}\right) + \left(\frac{1}{4}\right)\left(\frac{1}{5}\right) + \left(\frac{1}{4}\right)\left(\frac{1}{5}\right)$$
#
# $$\text{MSE} = \frac{1}{72} + \frac{5}{72} + \frac{1}{20} + \frac{1}{20} = \frac{6}{72} + \frac{2}{20} = \frac{1}{12} + \frac{1}{10} = \frac{11}{60} \approx 0.1833$$
#
# <br>
#
# 9. How would the **Mean Square Error (MSE)** change if the bank decided to ignore the customer risk class $Y$ and instead used the global average fraud rate ($E[X] = 0.30$) as a constant estimate for every transaction? Calculate this error and explain its relationship to the **Law of Total Variance**.
#
# $$\text{New MSE} = \text{Var}(X) = \mathbb{E}[(X - \mathbb{E}[X])^2] = \mathbb{E}[X^2] - (\mathbb{E}[X])^2$$
#
# $$\mathbb{E}[X^2] = 0^2(0.70) + 1^2(0.30) = 0.30$$
#
# $$\text{New MSE} = 0.30 - (0.30)^2 = 0.30 - 0.09 = 0.21$$
#
# MSE increases from $\approx 0.1833$ to $0.21$
#
# The difference is explained by the Law of Total Variance. When we ignore the customer's risk class, our Mean Square Error is simply the total variance of the data 0.21. When we utilize the risk class, our error drops to the expected conditional variance roughly 0.1833. The gap between these two errors represents the variance of the conditional expectation which is essentially the valuable, predictable information about fraud rates that the bank loses by throwing away the risk category.
#
# <br>
#
# 10. Using the joint distribution of $(X, Y)$ derived from the sample space:
#
#     a) Compute the entropy $H(X)$, representing the bank's initial uncertainty regarding fraud.
#
#     $$P(X=0) = 0.70, \quad P(X=1) = 0.30$$
#
#     $$H(X) = -0.7 \log_2(0.7) - 0.3 \log_2(0.3) \approx 0.3602 + 0.5211 \approx 0.8813 \text{ bits}$$
#
#     <br>
#
#     b) Compute the conditional entropy $H(X \mid Y)$, representing the uncertainty remaining after the customer's risk class is revealed.
#
#     $$H(X \mid Y=0) = -\frac{5}{6} \log_2\left(\frac{5}{6}\right) - \frac{1}{6} \log_2\left(\frac{1}{6}\right) \approx 0.6500 \text{ bits}$$
#
#     $$H(X \mid Y=1) = -\frac{1}{2} \log_2\left(\frac{1}{2}\right) - \frac{1}{2} \log_2\left(\frac{1}{2}\right) = 1.0000 \text{ bit}$$
#
#     $$H(X \mid Y) = P(Y=0)H(X \mid Y=0) + P(Y=1)H(X \mid Y=1)$$
#
#     $$H(X \mid Y) \approx 0.60(0.6500) + 0.40(1.0000) = 0.3900 + 0.4000 = 0.7900 \text{ bits}$$
#
#     <br>
#
#     c) Calculate the Mutual Information $I(X; Y)$.
#
#     $$I(X;Y) = H(X) - H(X \mid Y) \approx 0.8813 - 0.7900 = 0.0913 \text{ bits}$$
#
#     <br>
#
#     d) Based on these values, what percentage of the total uncertainty about fraud is removed by knowing the customer's risk class?
#
#     $$\text{Percentage} = \left( \frac{I(X;Y)}{H(X)} \right) \times 100 \approx \left( \frac{0.0913}{0.8813} \right) \times 100 \approx 10.36\%$$

# %% [markdown]
# # Q2) Conditional Density of the Multivariate Gaussian

# %% [markdown]
# Let $\mathbf{Z}$ be the concatenated random matrix
# $\mathbf{Z} = \begin{bmatrix} \mathbf{X} \\ \mathbf{Y} \end{bmatrix} \in \mathbb{R}^{n+m}$.
#
#
# The random variable $\mathbf{Z}$ is said to have a **joint multivariate normal distribution** if every linear combination of its components follows a univariate normal distribution.
#
# For $\mathbf{Z}$ to possess a **joint density function** (meaning its distribution is absolutely continuous with respect to the Lebesgue measure on $\mathbb{R}^{n+m}$), its covariance matrix must be non-singular (positive definite).
#
#
# The joint density function $f_{\mathbf{X}, \mathbf{Y}}(\mathbf{z})$ for $\mathbf{z} \in \mathbb{R}^{n+m}$ is given by:
#
# $$f_{\mathbf{X}, \mathbf{Y}}(\mathbf{z}) = \frac{1}{\sqrt{(2\pi)^{n+m} |\boldsymbol{\Sigma}|}} \exp\left( -\frac{1}{2} (\mathbf{z} - \boldsymbol{\mu})^T \boldsymbol{\Sigma}^{-1} (\mathbf{z} - \boldsymbol{\mu}) \right).$$
#
# Here:
#
# * **Mean ($\boldsymbol{\mu}$):** $\boldsymbol{\mu} = E[\mathbf{Z}] = \begin{bmatrix} \boldsymbol{\mu}_X \\ \boldsymbol{\mu}_Y \end{bmatrix} \in \mathbb{R}^{n+m}$, where $\boldsymbol{\mu}_X \in \mathbb{R}^n$ and $\boldsymbol{\mu}_Y \in \mathbb{R}^m$.
# * **Covariance Matrix ($\boldsymbol{\Sigma}$):** A symmetric, positive definite matrix $\boldsymbol{\Sigma} \in \mathbb{R}^{(n+m) \times (n+m)}$ partitioned as:
# $$\boldsymbol{\Sigma} = \begin{bmatrix} \boldsymbol{\Sigma}_{XX} & \boldsymbol{\Sigma}_{XY} \\ \boldsymbol{\Sigma}_{YX} & \boldsymbol{\Sigma}_{YY} \end{bmatrix}$$
#     * $\boldsymbol{\Sigma}_{XX} = \text{Var}(\mathbf{X})$ (size $n \times n$)
#     * $\boldsymbol{\Sigma}_{YY} = \text{Var}(\mathbf{Y})$ (size $m \times m$)
#     * $\boldsymbol{\Sigma}_{XY} = \text{Cov}(\mathbf{X}, \mathbf{Y}) = \boldsymbol{\Sigma}_{YX}^T$ (size $n \times m$)
# * **Determinant ($|\boldsymbol{\Sigma}|$):** The normalization factor ensuring the total integral is 1.
#
# 1. Show that the conditional distribution is given by $f_{\mathbf{X}|\mathbf{Y}}(\mathbf{x} \mid \mathbf{y})$
#
# $$f_{\mathbf{X}|\mathbf{Y}}(\mathbf{x} \mid \mathbf{y}) = \frac{1}{\sqrt{(2\pi)^n |\mathbf{S}_{XX}|}} \exp\left( -\frac{1}{2} (\mathbf{x} - \boldsymbol{\mu}^*)^T \boldsymbol{\Sigma}_{X\mid Y}^{-1} (\mathbf{x} - \boldsymbol{\mu}^*) \right),$$
# where
# * $\boldsymbol{\Sigma}_{X\mid Y} = \boldsymbol{\Sigma}_{XX} - \boldsymbol{\Sigma}_{XY}\boldsymbol{\Sigma}_{YY}^{-1}\boldsymbol{\Sigma}_{YX}$
# * $\boldsymbol{\mu}^* = \boldsymbol{\mu}_x + \boldsymbol{\Sigma}_{XY}\boldsymbol{\Sigma}_{YY}^{-1}(\mathbf{y} - \boldsymbol{\mu}_y)$

# %% [markdown]
# Define a new random vector $\mathbf{W}$ that is independent of $\mathbf{Y}$ by ensuring their covariance is zero.
#
# $$\mathbf{W} = \mathbf{X} - \mathbf{A}\mathbf{Y}$$
#
# $$\text{Cov}(\mathbf{W}, \mathbf{Y}) = 0$$
#
# $$\text{Cov}(\mathbf{X} - \mathbf{A}\mathbf{Y}, \mathbf{Y}) = 0$$
#
# $$\boldsymbol{\Sigma}_{XY} - \mathbf{A}\boldsymbol{\Sigma}_{YY} = 0$$
#
# $$\mathbf{A} = \boldsymbol{\Sigma}_{XY}\boldsymbol{\Sigma}_{YY}^{-1}$$
#
# $$\mathbf{W} = \mathbf{X} - \boldsymbol{\Sigma}_{XY}\boldsymbol{\Sigma}_{YY}^{-1}\mathbf{Y}$$
#
# Expected value and variance of vector $\mathbf{W}$,
#
# $$E[\mathbf{W}] = E[\mathbf{X} - \boldsymbol{\Sigma}_{XY}\boldsymbol{\Sigma}_{YY}^{-1}\mathbf{Y}] = \boldsymbol{\mu}_X - \boldsymbol{\Sigma}_{XY}\boldsymbol{\Sigma}_{YY}^{-1}\boldsymbol{\mu}_Y$$
#
# $$\text{Var}(\mathbf{W}) = \text{Var}(\mathbf{X} - \mathbf{A}\mathbf{Y})$$
#
# $$\text{Var}(\mathbf{W}) = \boldsymbol{\Sigma}_{XX} - \boldsymbol{\Sigma}_{XY}\mathbf{A}^T - \mathbf{A}\boldsymbol{\Sigma}_{YX} + \mathbf{A}\boldsymbol{\Sigma}_{YY}\mathbf{A}^T$$
#
# $$\text{Var}(\mathbf{W}) = \boldsymbol{\Sigma}_{XX} - \boldsymbol{\Sigma}_{XY}(\boldsymbol{\Sigma}_{YY}^{-1}\boldsymbol{\Sigma}_{YX}) - (\boldsymbol{\Sigma}_{XY}\boldsymbol{\Sigma}_{YY}^{-1})\boldsymbol{\Sigma}_{YX} + (\boldsymbol{\Sigma}_{XY}\boldsymbol{\Sigma}_{YY}^{-1})\boldsymbol{\Sigma}_{YY}(\boldsymbol{\Sigma}_{YY}^{-1}\boldsymbol{\Sigma}_{YX})$$
#
# $$\text{Var}(\mathbf{W}) = \boldsymbol{\Sigma}_{XX} - \boldsymbol{\Sigma}_{XY}\boldsymbol{\Sigma}_{YY}^{-1}\boldsymbol{\Sigma}_{YX} = \boldsymbol{\Sigma}_{X|Y}$$
#
# <br>
#
# $$\mathbf{X} = \mathbf{W} + \boldsymbol{\Sigma}_{XY}\boldsymbol{\Sigma}_{YY}^{-1}\mathbf{Y}$$
#
# $$(\mathbf{X} \mid \mathbf{Y} = \mathbf{y}) = \mathbf{W} + \boldsymbol{\Sigma}_{XY}\boldsymbol{\Sigma}_{YY}^{-1}\mathbf{y}$$
#
# The conditional mean and conditional variance,
#
# $$E[\mathbf{X} \mid \mathbf{Y} = \mathbf{y}] = E[\mathbf{W}] + \boldsymbol{\Sigma}_{XY}\boldsymbol{\Sigma}_{YY}^{-1}\mathbf{y}$$
#
# $$E[\mathbf{X} \mid \mathbf{Y} = \mathbf{y}] = \boldsymbol{\mu}_X - \boldsymbol{\Sigma}_{XY}\boldsymbol{\Sigma}_{YY}^{-1}\boldsymbol{\mu}_Y + \boldsymbol{\Sigma}_{XY}\boldsymbol{\Sigma}_{YY}^{-1}\mathbf{y}$$
#
# $$E[\mathbf{X} \mid \mathbf{Y} = \mathbf{y}] = \boldsymbol{\mu}_X + \boldsymbol{\Sigma}_{XY}\boldsymbol{\Sigma}_{YY}^{-1}(\mathbf{y} - \boldsymbol{\mu}_Y) = \boldsymbol{\mu}^*$$
#
# $$\text{Var}(\mathbf{X} \mid \mathbf{Y} = \mathbf{y}) = \text{Var}(\mathbf{W}) = \boldsymbol{\Sigma}_{X|Y}$$
#
# <br>
#
# Substitute the conditional mean and covariance into the standard multivariate Gaussian formula,
#
# $$f_{\mathbf{X}|\mathbf{Y}}(\mathbf{x} \mid \mathbf{y}) = \frac{1}{\sqrt{(2\pi)^n |\boldsymbol{\Sigma}_{X|Y}|}} \exp\left( -\frac{1}{2}(\mathbf{x} - \boldsymbol{\mu}^*)^T \boldsymbol{\Sigma}_{X|Y}^{-1} (\mathbf{x} - \boldsymbol{\mu}^*) \right)$$
#
# <br>

# %% [markdown]
# # Q3) Continuous Fault Monitoring of a Spindle Motor

# %% [markdown]
# A factory monitors the health of a high-speed CNC spindle. The critical variable is the **Internal Temperature ($X$)**, but because the motor is sealed, they can only observe the **Total Spindle Power ($Y$)**.
#
# **The Setup:**
# 1.  **Hidden Temperature ($X$):** The standardized temperature deviation follows a standard normal distribution:
#     $$X \sim \mathscr{N}(0, 1)$$
# 2.  **Mechanical Load ($Q$):** The torque required to cut material creates "noise" in the power reading. It is independent of temperature and follows:
#     $$Q \sim \mathscr{N}(0, 4)$$
# 3.  **The Measurement ($Y$):** The power sensor $Y$ measures the combined effect of thermal load and mechanical torque:
# $$Y = X + Q$$
#
# ---
#
# **Answer the followings:**

# %% [markdown]
# **1. Joint Distribution**
# Identify the distribution of the random varaible $(X, Y)$.
# * Show that $Y \sim \mathscr{N}(0, 5)$.
# * Find the covariance $\text{Cov}(X, Y)$.
#
# <br>
#
# * $Y \sim \mathcal{N}(0, 5)$,
#
# $$E[Y] = E[X + Q] = E[X] + E[Q] = 0 + 0 = 0$$$$Var(Y) = Var(X + Q) = Var(X) + Var(Q) = 1 + 4 = 5$$
#
# <br>
#
# * $$Cov(X, Y) = Cov(X, X + Q) = Cov(X, X) + Cov(X, Q) = Var(X) + 0 = 1$$
#
# <br>
#
# **2. Information Geometry**
# Explain why $X$ is **not** $\sigma(Y)$-measurable. In practical terms, if the power meter shows $Y = 5$, why can't the engineer know for certain if the motor is overheating ($X$ is high) or if the material being cut is simply very hard ($Q$ is high)?
#
# <br>
#
# A random variable $X$ is $\sigma(Y)$ measurable if its exact value can be perfectly deduced solely by knowing the value of $Y$. In this scenario, $Y = X + Q$. If the power meter reads $Y = 5$, there are infinitely many combinations of temperature $X$ and mechanical load $Q$ that could add up to 5.
#
# <br>
#
# **3. Conditional Expectation (The Best Estimate)**
# Compute the conditional expectation $E[X \mid Y]$.
# * Using the property for joint normals: $E[X \mid Y = y] = \mu_X + \frac{\text{Cov}(X,Y)}{\text{Var}(Y)}(y - \mu_Y)$.
# * Express this as a "signal-to-total-variance" ratio.
#
# <br>
#
# * $E[X \mid Y]$,
#
# $$E[X \mid Y=y] = \mu_X + \frac{Cov(X,Y)}{Var(Y)}(y - \mu_Y)$$
#
# $$E[X \mid Y] = 0 + \frac{1}{5}(Y - 0) = \frac{1}{5}Y$$
#
# <br>
#
# * $$\text{Ratio} = \frac{Cov(X,Y)}{Var(Y)} = \frac{Var(X)}{Var(X) + Var(Q)} = \frac{1}{1 + 4} = \frac{1}{5}$$
#
# <br>
#
# **4. Verification of the Residual**
# Let $\widehat{X} = E[X \mid Y]$. Define the estimation error (residual) as $Z = X - \widehat{X}$.
# * Prove that $E[Z] = 0$.
# * Verify that the error $Z$ is uncorrelated with the observation $Y$ (the Orthogonality Principle).
#
# <br>
#
# * $$E[Z] = E\left[X - \frac{1}{5}Y\right] = E[X] - \frac{1}{5}E[Y] = 0 - \frac{1}{5}(0) = 0$$
#
# <br>
#
# * $$Cov(Z, Y) = Cov\left(X - \frac{1}{5}Y, Y\right) = Cov(X, Y) - \frac{1}{5}Cov(Y, Y)$$
#
# $$Cov(Z, Y) = Cov(X, Y) - \frac{1}{5}Var(Y)$$
#
# $$Cov(Z, Y) = 1 - \frac{1}{5}(5) = 1 - 1 = 0$$
#
# <br>
#
# **5. Information Theory: Differential Entropy**
# * Compute the differential entropy $h(X)$.
# * Compute the conditional differential entropy $h(X \mid Y)$.
# * *Note: The variance of the conditional distribution $(X \mid Y=y)$ is given by $\sigma_{X|Y}^2 = \sigma_X^2 - \frac{\text{Cov}(X,Y)^2}{\text{Var}(Y)}$.*
#
# <br>
#
# * $$h(X) = \frac{1}{2} \log_2(2\pi e \sigma_X^2) = \frac{1}{2} \log_2(2\pi e (1)) = \frac{1}{2} \log_2(2\pi e)$$
#
# <br>
#
# * $$\sigma^2_{X|Y} = \sigma^2_X - \frac{Cov(X,Y)^2}{Var(Y)} = 1 - \frac{1^2}{5} = \frac{4}{5}$$
#
# $$h(X \mid Y) = \frac{1}{2} \log_2(2\pi e \sigma^2_{X|Y}) = \frac{1}{2} \log_2\left(2\pi e \left(\frac{4}{5}\right)\right)$$
#
# <br>
#
# **6. Mutual Information**
# Calculate $I(X; Y) = h(X) - h(X \mid Y)$.
# * What percentage of the "uncertainty" about the temperature is removed by observing the power meter?
# * How would this change if the mechanical noise $Q$ had a variance of $100$ instead of $4$?
#
# <br>
#
# * $$I(X;Y) = h(X) - h(X \mid Y)$$
#
# $$I(X;Y) = \frac{1}{2} \log_2(2\pi e) - \frac{1}{2} \log_2\left(2\pi e \left(\frac{4}{5}\right)\right)$$
#
# $$I(X;Y) = \frac{1}{2} \log_2\left(\frac{2\pi e}{2\pi e (4/5)}\right) = \frac{1}{2} \log_2\left(\frac{5}{4}\right) \approx 0.1609 \text{ bits}$$
#
# <br>
#
# * $$\text{Percentage} = \frac{I(X;Y)}{h(X)} \times 100 = \frac{\frac{1}{2} \log_2(1.25)}{\frac{1}{2} \log_2(2\pi e)} \times 100 \approx \frac{0.3219}{4.0943} \times 100 \approx 7.86\%$$
#
# <br>
#
# * $$\text{New } Var(Y) = Var(X) + Var(Q) = 1 + 100 = 101$$
#
# $$\text{New } \sigma^2_{X|Y} = 1 - \frac{1}{101} = \frac{100}{101}$$
#
# $$\text{New } I(X;Y) = \frac{1}{2} \log_2\left(\frac{101}{100}\right) \approx 0.007 \text{ bits}$$
#
# The mutual information drops drastically, meaning almost $0\%$ of the uncertainty is removed because the noise completely overwhelms the signal.
#
# <br>
#
# **7. Diagnostic Interpretation**
# The factory manager says: *"Since $Y = X + Q$, our best estimate of temperature should just be $Y$ itself."*
# Using your result from Question 3, explain why $Y$ is a **biased** estimator of $X$ and why $E[X \mid Y]$ "shrinks" the measurement toward the mean (zero).
#
# <br>
#
# Guessing that $X$ equals $Y$ is flawed because the noise ($Q$) is four times larger than the actual signal $X$. Therefore, extreme readings are usually just loud noise.The conditional expectation, $E[X \mid Y] = \frac{1}{5}Y$, fixes this by acting as a shrinkage estimator. Because the real temperature signal only accounts for 1/5 th of the total variance, the formula scales the measurement down to 20%. This safely shrinks your estimate back toward the average to filter out the heavy mechanical noise.
#
# <br>
